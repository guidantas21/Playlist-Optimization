# %%
from concorde.tsp import TSPSolver
import tsplib95

import numpy as np
import json
import re

# %%
PARAMETERS_FILE = '../parameters.json'

# %%
with open(PARAMETERS_FILE) as f:
    parameters = json.load(f)

pattern = r'/playlist/([^/?]+)'

playlist_id = list()

for url in parameters['playlist_id']:
    match = re.search(pattern, url)

    if match:
        playlist_id.append(match.group(1))

playlist_id
# Out:
# ['3tTo8cKpIQbLJ3MTzgEVjV', '1Kzd8jonR1022i8dL8eDda', '3bxNKleDijOT6Did05jINs']

# %%
data = dict()

for _id in playlist_id:
    with open(f"../data/metadata/{_id}.json") as f:
        data[_id] = json.load(f)

# %%
def compare_artist_album_similarity(data_a:dict, data_b:dict) -> int:
    distance = 0

    if (data_a["artist"] == data_b["artist"]):
        distance += parameters["same_artist_bonus"]
        
        if (data_a["album"] == data_b["album"]):
            distance += parameters["same_album_bonus"]

    return distance


def compare_intersections(a:list, b:list, multiplier:list) -> int:
    if a and b:
        set_a = set(a)
        set_b = set(b)

        intersection = set_a.intersection(set_b)

        intersection_size = len(intersection)

        if intersection_size > 0:
        
            total_size = len(set_a) + len(set_b)

            CONSTANT = 100

            similarity = (intersection_size / total_size) * CONSTANT

            return similarity *multiplier

    return 0

# %%
def initialize_adjacency_matrix(size:int) -> list:
    return [[0 for col in range(size)] for row in range(size)]


def populate_adjacency_matrix(adjacency_matrix:list, size:int, data) -> list:
    for i in range(size):
        for j in range(size):
            if i != j:
                distance = parameters['initial_distance']

                distance -= compare_artist_album_similarity(data[i], data[j])

                distance -= compare_intersections(
                    data[i]["genres"], data[j]["genres"], parameters["genres_intersection_multiplier"])
                distance -= compare_intersections(
                    data[i]["related_genres"], data[j]["related_genres"], parameters["related_genres_intersection_multiplier"])
                distance -= compare_intersections(
                    data[i]["related_artists"], data[j]["related_artists"], parameters["related_artists_intersection_multiplier"])
                distance -= compare_intersections(
                    data[i]["generic_genres"], data[j]["generic_genres"], parameters["generic_genres_intersection_multiplier"])

                adjacency_matrix[i][j] = int(distance);
    
    return adjacency_matrix


def print_adjacency_matrix(adjacency_matrix:list, size:int) -> None:
    for i in range(size):
        for j in range(size):
            print("{}".format(adjacency_matrix[i][j]), end=" ")
        print()

# %%
for _id, _metadata in data.items():
    print(_id, _metadata)

    SIZE = len(_metadata)
    adjacency_matrix = initialize_adjacency_matrix(SIZE)
    adjacency_matrix = populate_adjacency_matrix(adjacency_matrix, SIZE, _metadata)
    # print_adjacency_matrix(adjacency_matrix, SIZE)

    problem = tsplib95.models.StandardProblem()

    problem.name = _id
    problem.type = "TSP"
    problem.dimension = SIZE
    problem.edge_weight_type = "EXPLICIT"
    problem.edge_weight_format = "FULL_MATRIX"
    problem.node_coord_type = "NO_COORDS"
    problem.display_data_type = "NO_DISPLAY"
    problem.edge_weights = np.array(adjacency_matrix).tolist()

    problem.save(f"../data/tsp/{_id}.tsp")
# Out:
# 3tTo8cKpIQbLJ3MTzgEVjV [{'id': '4sQdW03IQh3tsZeBELdt5G', 'name': 'Foxey Lady', 'album': 'Are You Experienced', 'artist': 'Jimi Hendrix', 'genres': ['acid rock', 'album rock', 'classic rock', 'hard rock', 'proto-metal', 'psychedelic rock', 'rock'], 'related_artists': ['Cream', 'The Yardbirds', 'Canned Heat', 'Derek & The Dominos', 'Steppenwolf', 'Janis Joplin', 'Ten Years After', 'Free', 'Jefferson Airplane', 'The Doors', 'The Animals', 'Big Brother & The Holding Company', 'Stevie Ray Vaughan', 'Rory Gallagher', 'Jim Morrison', 'Traffic', 'John Mayall & The Bluesbreakers', 'Allman Brothers Band', 'Albert King', 'The Who'], 'related_genres': ['roots rock', 'southern rock', 'blues rock', 'heartland rock', 'texas blues', 'soul blues', 'electric blues', 'jam band', 'blues', 'soft rock', 'singer-songwriter', 'traditional blues', 'mellow gold', 'symphonic rock', 'folk rock', 'british invasion', 'progressive rock', 'british blues', 'supergroup', 'country rock', 'folk', 'protopunk', 'classic canadian rock', 'memphis soul', 'art rock', 'instrumental rock'], 'generic_genres': ['rock', 'rock', 'rock', 'rock', 'metal', 'rock', 'rock', 'rock', 'rock', 'rock', 'blues', 'rock', 'blues', 'blues', 'soul', 'blues', 'blues', 'rock', 'blues', 'rock', 'rock', 'folk', 'invasion', 'rock', 'blues', 'rock', 'country', 'folk', 'punk', 'rock', 'soul', 'rock', 'rock'], 'release_date': '1967-05-12', 'duration_ms': 199186, 'popularity': 46, 'acousticness': 0.0612, 'danceability': 0.507, 'energy': 0.851, 'instrumentalness': 0.157, 'key': 4, 'liveness': 0.371, 'loudness': -5.995, 'mode': 1, 'speechiness': 0.0386, 'tempo': 98.061, 'time_signature': 4, 'valence': 0.587}, {'id': '6DRtSttaJsE8fstgTRll3p', 'name': 'Manic Depression', 'album': 'Are You Experienced', 'artist': 'Jimi Hendrix', 'genres': ['acid rock', 'album rock', 'classic rock', 'hard rock', 'proto-metal', 'psychedelic rock', 'rock'], 'related_artists': ['Cream', 'The Yardbirds', 'Canned Heat', 'Derek & The Dominos', 'Steppenwolf', 'Janis Joplin', 'Ten Years After', 'Free', 'Jefferson Airplane', 'The Doors', 'The Animals', 'Big Brother & The Holding Company', 'Stevie Ray Vaughan', 'Rory Gallagher', 'Jim Morrison', 'Traffic', 'John Mayall & The Bluesbreakers', 'Allman Brothers Band', 'Albert King', 'The Who'], 'related_genres': ['roots rock', 'southern rock', 'blues rock', 'heartland rock', 'texas blues', 'soul blues', 'electric blues', 'jam band', 'blues', 'soft rock', 'singer-songwriter', 'traditional blues', 'mellow gold', 'symphonic rock', 'folk rock', 'british invasion', 'progressive rock', 'british blues', 'supergroup', 'country rock', 'folk', 'protopunk', 'classic canadian rock', 'memphis soul', 'art rock', 'instrumental rock'], 'generic_genres': ['rock', 'rock', 'rock', 'rock', 'metal', 'rock', 'rock', 'rock', 'rock', 'rock', 'blues', 'rock', 'blues', 'blues', 'soul', 'blues', 'blues', 'rock', 'blues', 'rock', 'rock', 'folk', 'invasion', 'rock', 'blues', 'rock', 'country', 'folk', 'punk', 'rock', 'soul', 'rock', 'rock'], 'release_date': '1967-05-12', 'duration_ms': 222226, 'popularity': 39, 'acousticness': 0.0132, 'danceability': 0.351, 'energy': 0.969, 'instrumentalness': 0.0619, 'key': 1, 'liveness': 0.151, 'loudness': -4.924, 'mode': 1, 'speechiness': 0.129, 'tempo': 149.687, 'time_signature': 3, 'valence': 0.747}, {'id': '7bbf6izisrvlYdFVGeV8q9', 'name': 'Red House', 'album': 'Are You Experienced', 'artist': 'Jimi Hendrix', 'genres': ['acid rock', 'album rock', 'classic rock', 'hard rock', 'proto-metal', 'psychedelic rock', 'rock'], 'related_artists': ['Cream', 'The Yardbirds', 'Canned Heat', 'Derek & The Dominos', 'Steppenwolf', 'Janis Joplin', 'Ten Years After', 'Free', 'Jefferson Airplane', 'The Doors', 'The Animals', 'Big Brother & The Holding Company', 'Stevie Ray Vaughan', 'Rory Gallagher', 'Jim Morrison', 'Traffic', 'John Mayall & The Bluesbreakers', 'Allman Brothers Band', 'Albert King', 'The Who'], 'related_genres': ['roots rock', 'southern rock', 'blues rock', 'heartland rock',  ...
# 1Kzd8jonR1022i8dL8eDda [{'id': '0NWPxcsf5vdjdiFUI8NgkP', 'name': 'Hey Joe', 'album': 'Are You Experienced', 'artist': 'Jimi Hendrix', 'genres': ['acid rock', 'album rock', 'classic rock', 'hard rock', 'proto-metal', 'psychedelic rock', 'rock'], 'related_artists': ['Cream', 'The Yardbirds', 'Canned Heat', 'Derek & The Dominos', 'Steppenwolf', 'Janis Joplin', 'Ten Years After', 'Free', 'Jefferson Airplane', 'The Doors', 'The Animals', 'Big Brother & The Holding Company', 'Stevie Ray Vaughan', 'Rory Gallagher', 'Jim Morrison', 'Traffic', 'John Mayall & The Bluesbreakers', 'Allman Brothers Band', 'Albert King', 'The Who'], 'related_genres': ['roots rock', 'southern rock', 'blues rock', 'heartland rock', 'texas blues', 'soul blues', 'electric blues', 'jam band', 'blues', 'soft rock', 'singer-songwriter', 'traditional blues', 'mellow gold', 'symphonic rock', 'folk rock', 'british invasion', 'progressive rock', 'british blues', 'supergroup', 'country rock', 'folk', 'protopunk', 'classic canadian rock', 'memphis soul', 'art rock', 'instrumental rock'], 'generic_genres': ['rock', 'rock', 'rock', 'rock', 'metal', 'rock', 'rock', 'rock', 'rock', 'rock', 'blues', 'rock', 'blues', 'blues', 'soul', 'blues', 'blues', 'rock', 'blues', 'rock', 'rock', 'folk', 'invasion', 'rock', 'blues', 'rock', 'country', 'folk', 'punk', 'rock', 'soul', 'rock', 'rock'], 'release_date': '1967-05-12', 'duration_ms': 210160, 'popularity': 71, 'acousticness': 0.00603, 'danceability': 0.346, 'energy': 0.768, 'instrumentalness': 0.38, 'key': 9, 'liveness': 0.0244, 'loudness': -5.695, 'mode': 1, 'speechiness': 0.0377, 'tempo': 169.492, 'time_signature': 4, 'valence': 0.532}, {'id': '2MuWTIM3b0YEAskbeeFE1i', 'name': 'Master Of Puppets', 'album': 'Master Of Puppets (Remastered)', 'artist': 'Metallica', 'genres': ['hard rock', 'metal', 'old school thrash', 'rock', 'thrash metal'], 'related_artists': ['Megadeth', 'Slayer', 'Pantera', 'Judas Priest', 'Motörhead', 'Black Label Society', 'Anthrax', 'Iron Maiden', 'Testament', 'Machine Head', 'Black Sabbath', 'Danzig', 'Ozzy Osbourne', 'Sepultura', 'Dio', 'White Zombie', 'Alice In Chains', 'Kreator', 'Lamb of God', 'Airbourne'], 'related_genres': ['punk', 'classic rock', 'progressive groove metal', 'glam metal', 'nwobhm', 'melodic groove metal', 'album rock', 'grunge', 'brazilian metal', 'german metal', 'nu metal', 'texas metal', 'groove metal', 'birmingham metal', 'latin metal', 'brazilian groove metal', 'rap metal', 'german thrash metal', 'virginia metal', 'speed metal', 'metal mineiro', 'alternative metal', 'death metal', 'uk doom metal', 'deathrash', 'stoner rock', 'alternative rock', 'melodic thrash', 'brazilian thrash metal', 'industrial metal', 'melodic metalcore', 'post-grunge'], 'generic_genres': ['rock', 'metal', 'rock', 'metal', 'punk', 'rock', 'metal', 'metal', 'metal', 'rock', 'grunge', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'latin', 'metal', 'rap', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'metal', 'rock', 'rock', 'metal', 'metal', 'metal', 'metalcore', 'post-grunge', 'grunge'], 'release_date': '1986-03-03', 'duration_ms': 515386, 'popularity': 79, 'acousticness': 0.000647, 'danceability': 0.543, 'energy': 0.836, 'instrumentalness': 0.431, 'key': 4, 'liveness': 0.153, 'loudness': -9.11, 'mode': 0, 'speechiness': 0.0353, 'tempo': 105.173, 'time_signature': 4, 'valence': 0.56}, {'id': '0V3wPSX9ygBnCm8psDIegu', 'name': 'Anti-Hero', 'album': 'Midnights', 'artist': 'Taylor Swift', 'genres': ['pop'], 'related_artists': ['Demi Lovato', 'Selena Gomez', 'Harry Styles', 'Alessia Cara', 'Katy Perry', 'One Direction', 'Meghan Trainor', 'Camila Cabello', 'Niall Horan', 'Ariana Grande', 'Selena Gomez & The Scene', 'Fifth Harmony', 'Dua Lipa', 'Halsey', 'Troye Sivan', 'The 1975', 'Jonas Brothers', '5 Seconds of Summer', 'Little Mix', 'Sabrina Carpenter'], 'related_genres': ['modern rock', 'rock', 'electropop', 'etherpop', 'boy band', 'modern alternative rock', 'canadian pop', 'aus ...
# 3bxNKleDijOT6Did05jINs [{'id': '6mjHiGwrRGE8LVCXVc5QDU', 'name': 'Out Of Control', 'album': 'The Reason (15th Anniversary Deluxe)', 'artist': 'Hoobastank', 'genres': ['alternative metal', 'funk metal', 'nu metal', 'pop rock', 'post-grunge'], 'related_artists': ['12 Stones', 'Crossfade', 'Seether', 'Sick Puppies', 'Trapt', 'TRUSTcompany', '3 Doors Down', 'Fuel', 'Dead By Sunrise', '10 Years', 'Default', 'Finger Eleven', 'The Exies', 'Shinedown', 'Smile Empty Soul', 'Breaking Benjamin', 'Puddle Of Mudd', 'Chevelle', 'Cold', 'Papa Roach'], 'related_genres': ['rap metal', 'christian rock', 'rock', 'canadian rock', 'alabama metal', 'south african rock', 'industrial metal', 'christian hard rock', 'electronic rock', 'rap rock'], 'generic_genres': ['metal', 'metal', 'metal', 'pop', 'rock', 'post-grunge', 'grunge', 'rap', 'metal', 'rock', 'rock', 'rock', 'metal', 'rock', 'metal', 'rock', 'rock', 'electro', 'rap', 'rock'], 'release_date': '2003-12-09', 'duration_ms': 162106, 'popularity': 66, 'acousticness': 0.00161, 'danceability': 0.443, 'energy': 0.973, 'instrumentalness': 0, 'key': 4, 'liveness': 0.353, 'loudness': -4.386, 'mode': 0, 'speechiness': 0.133, 'tempo': 157.872, 'time_signature': 4, 'valence': 0.458}, {'id': '7iL6o9tox1zgHpKUfh9vuC', 'name': 'In Da Club', 'album': "Get Rich Or Die Tryin'", 'artist': '50 Cent', 'genres': ['east coast hip hop', 'gangster rap', 'hip hop', 'pop rap', 'queens hip hop', 'rap'], 'related_artists': ['G-Unit', 'The Game', 'Lloyd Banks', 'Obie Trice', 'D12', 'Fabolous', 'Xzibit', 'Fat Joe', 'Ja Rule', 'DMX', 'Busta Rhymes', 'Mobb Deep', 'Dr. Dre', 'Diddy', 'T.I.', 'Snoop Dogg', 'Makaveli', 'Ludacris', 'The Notorious B.I.G.', 'Rick Ross'], 'related_genres': ['atl hip hop', 'dirty south rap', 'singeli', 'bronx hip hop', 'urban contemporary', 'nyc rap', 'old school atlanta hip hop', 'hardcore hip hop', 'dance pop', 'trap', 'detroit hip hop', 'southern hip hop', 'west coast rap', 'g funk', 'hip pop'], 'generic_genres': ['hip hop', 'rap', 'hip hop', 'pop', 'rap', 'hip hop', 'rap', 'hip hop', 'rap', 'hip hop', 'rap', 'hip hop', 'hip hop', 'pop', 'dance', 'rap', 'trap', 'hip hop', 'hip hop', 'rap', 'pop', 'hip pop'], 'release_date': '2003-02-06', 'duration_ms': 193466, 'popularity': 84, 'acousticness': 0.255, 'danceability': 0.899, 'energy': 0.713, 'instrumentalness': 0, 'key': 6, 'liveness': 0.0708, 'loudness': -2.752, 'mode': 0, 'speechiness': 0.366, 'tempo': 90.051, 'time_signature': 4, 'valence': 0.777}, {'id': '3yfqSUWxFvZELEM4PmlwIR', 'name': 'The Real Slim Shady', 'album': 'The Marshall Mathers LP', 'artist': 'Eminem', 'genres': ['detroit hip hop', 'hip hop', 'rap'], 'related_artists': ['D12', 'The Game', 'Bad Meets Evil', 'DMX', 'Dr. Dre', '50 Cent', 'Hopsin', 'G-Unit', 'Tech N9ne', 'Snoop Dogg', 'Ice Cube', 'Xzibit', 'Yelawolf', 'T.I.', 'The Notorious B.I.G.', 'N.W.A.', 'Obie Trice', 'Eazy-E', 'Ludacris', 'Joyner Lucas'], 'related_genres': ['atl hip hop', 'pop rap', 'nyc rap', 'old school atlanta hip hop', 'hardcore hip hop', 'kansas city hip hop', 'alabama rap', 'golden age hip hop', 'old school hip hop', 'boston hip hop', 'southern hip hop', 'g funk', 'east coast hip hop', 'dirty south rap', 'queens hip hop', 'gangster rap', 'dance pop', 'trap', 'west coast rap', 'conscious hip hop'], 'generic_genres': ['hip hop', 'hip hop', 'rap', 'hip hop', 'pop', 'rap', 'rap', 'hip hop', 'hip hop', 'hip hop', 'rap', 'hip hop', 'hip hop', 'hip hop', 'hip hop', 'hip hop', 'rap', 'hip hop', 'rap', 'pop', 'dance', 'rap', 'trap', 'rap', 'hip hop'], 'release_date': '2000-05-23', 'duration_ms': 284200, 'popularity': 88, 'acousticness': 0.0302, 'danceability': 0.949, 'energy': 0.661, 'instrumentalness': 0, 'key': 5, 'liveness': 0.0454, 'loudness': -4.244, 'mode': 0, 'speechiness': 0.0572, 'tempo': 104.504, 'time_signature': 4, 'valence': 0.76}, {'id': '45hOioMDJktr86iKDHC8gr', 'name': 'Girlfriend', 'album': 'The Best Damn Thing (Expanded Edition)', 'artist': 'Avril Lavigne', 'genres': ['canadian pop', 'candy pop', ' ...

# %%
for _id, _metadata in data.items():
    solver = TSPSolver.from_tspfile(f"../data/tsp/{_id}.tsp")

    solution = solver.solve()

    solution_dict = dict()

    solution_dict['found_tour'] = solution.found_tour
    solution_dict['success'] = solution.success
    solution_dict['hit_timebound'] = solution.hit_timebound
    solution_dict['tour'] = solution.tour.tolist()
    solution_dict['optimal_value'] = solution.optimal_value

    solution_dict['tour_ids'] = [_metadata[vertex]['id'] for vertex in solution.tour]
    solution_dict['tour_names'] = [_metadata[vertex]['name'] for vertex in solution.tour]

    with open(f"../data/solutions/{_id}.json", "w") as f:
        json.dump(solution_dict, f, indent=4)
# Out:
# Problem Name: 3tTo8cKpIQbLJ3MTzgEVjV
# Problem Type: TSP
# Number of Nodes: 77
# Explicit Lengths (CC_MATRIXNORM)
# CCtsp_solve_dat ...
# Finding a good tour for compression ...
# linkern ...
# Setting kick type to close
# Starting Cycle: 27484
#    0 Steps   Best: 27447   0.01 seconds
#   20 Steps   Best: 27367   0.13 seconds
#   22 Steps   Best: 27364   0.14 seconds
#   30 Steps   Best: 27250   0.18 seconds
#   38 Total Steps.
# Best cycle length: 27250
# Lin-Kernighan Running Time: 0.23
# LK Initial Run: 27250.0
# LK Run 0: 27250.0
# LK Run from best tour: 27250.0
# Time to find compression tour: 0.79 (seconds)
# Set initial upperbound to 27250 (from tour)
# Fractional Matching: 25914.5
# Initial Running Time: 0.00 (seconds)
# Basis Running Time: 0.00 (seconds)
# Total fractional matching time: 0.00 (seconds)
# Total Time for first_lp: 0.00 (seconds)
# Setting upperbound to the initial bound: 27250.00
# Loading lp...done in 0.01 seconds
# LP has:  77 rows  165 columns  330 nonzeros
# Dual opt returned after 0.00 seconds
# Initial LP value: 25914.500000
# Setting tolerances: next cuts 13.3550 next round 1.3355
# CCtsp_init_edgegenerator (50)
# Using junk-norm nearest code
#  2117 edges
# LP has:  77 rows  165 columns  330 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  77 rows  165 columns  330 nonzeros
# Found  5 connect cuts in 0.00 seconds
#   Add  5 cuts (Total 3), LP: 26302.500000 (0.01 seconds)
# Found  7 segment cuts in 0.00 seconds
#   Add  7 cuts (Total 7), LP: 26997.500000 (0.00 seconds)
# Found  2 Fast Blossoms in 0.00 seconds
#   Add  2 cuts (Total 9), LP: 26997.500000 (0.00 seconds)
# Found  2 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  2 cuts (Total 11), LP: 26997.500000 (0.00 seconds)
# Block Combs
#   Type 0: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.01
# Found  0 block_combs in 0.01 seconds
# Found  5 exact subtours in 0.00 seconds
#   Add  5 cuts (Total 12), LP: 27199.000000 (0.00 seconds)
# Found  0 tighten_lp cuts (viol -0.0000) in 0.01 seconds
# Found  0 CLOSE tighten_lp cuts (viol -0.0000) in 0.00 seconds
# Found  0 double deckers (viol -0.0000) in 0.00 seconds
# Found  0 CLOSE double deckers (viol -0.0000) in 0.00 seconds
# CCtsp_generate_edges (20231)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 1 calls)
# Time for Add edges optimize: 0.00 seconds (0.01 total in 2 calls)
# CCtsp_generate_edges (20231)
# Time for Add edges optimize: 0.00 seconds (0.01 total in 3 calls)
# CCtsp_generate_edges (20231)
# Time for Add edges: 0.01 seconds (0.01 total in 1 calls)
# (SPARSE) 163 edges added, penalty 0.000000, val 24851.000000
# Time for Sparse edge check: 0.01 seconds (0.01 total in 1 calls)
# Write Pool: 3 cuts
# Time for Cutting inside loop: 0.06 seconds (0.06 total in 1 calls)
# LP has:  89 rows  328 columns  1195 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  89 rows  328 columns  928 nonzeros
# Found  6 connect cuts in 0.00 seconds
#   Add  6 cuts (Total 16), LP: 26040.000000 (0.00 seconds)
# Found  0 segment cuts in 0.00 seconds
# Found  4 Fast Blossoms in 0.00 seconds
#   Add  4 cuts (Total 20), LP: 26040.000000 (0.00 seconds)
# Found  2 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  2 cuts (Total 22), LP: 26040.000000 (0.00 seconds)
# Block Combs
#   Type 0: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 2: 1 cuts  0.3333 max violation  0.00 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.00
# Found  1 block_combs in 0.00 seconds
#   Add  1 cuts (Total 23), LP: 26040.000000 (0.00 seconds)
# Found  2 exact subtours in 0.00 seconds
#   Add  2 cuts (Total 21), LP: 26586.000000 (0.01 seconds)
# Found  7 tighten_lp cuts (viol 1.0000) in 0.00 seconds
#   Add  7 cuts (Total 28), LP: 26586.000000 (0.00 seconds)
# Found  1 CLOSE tighten_lp cuts (viol 0.5000) in 0.00 seconds
#   Add  1 cuts (Total 29), LP: 26586.000000 (0.00 seconds)
# Found  7 double deckers (viol 2.0000) in 0.01 seconds
#   Add  7 cuts (Total 36), LP: 26586.000000 (0.03 seconds)
# Found  0 CLOSE double deckers (viol -0.0000) in 0.00 seconds
# Found  0 Handling Inequalities (viol -0.0000) in 0.00 seconds
# Found  4 teethed combs (viol 2.0000) in 0.01 seconds
#   Add  4 cuts (Total 40), LP: 26586.000000 (0.19 seconds)
# CCtsp_generate_edges (20231)
# Time for Add edges optimize: 0.35 seconds (0.35 total in 4 calls)
# CCtsp_generate_edges (20231)
# Time for Add edges optimize: 0.16 seconds (0.51 total in 5 calls)
# CCtsp_generate_edges (20231)
# Time for Add edges: 0.52 seconds (0.53 total in 2 calls)
# (SPARSE) 179 edges added, penalty 0.000000, val 26453.000000
# Time for Sparse edge check: 0.52 seconds (0.54 total in 2 calls)
# Write Pool: 7 cuts
# Time for Cutting inside loop: 0.87 seconds (0.93 total in 2 calls)
# LP has:  117 rows  507 columns  3143 nonzeros
# Loading lp...done in 0.01 seconds
# LP has:  117 rows  507 columns  2547 nonzeros
# integral solution not connected
# Found  8 connect cuts in 0.00 seconds
#   Add  8 cuts (Total 34), LP: 26659.000000 (0.28 seconds)
# integral solution not connected
# Found  0 segment cuts in 0.00 seconds
# Found  0 Fast Blossoms in 0.00 seconds
# Found  0 Groetschel-Holland Blossoms in 0.00 seconds
# Block Combs
#   Type 0: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.00
# Found  0 block_combs in 0.00 seconds
# Found  5 exact subtours in 0.00 seconds
#   Add  5 cuts (Total 39), LP: 26659.000000 (0.05 seconds)
# integral solution not connected
# Found 22 tighten_lp cuts (viol 1.0000) in 0.02 seconds
#   Add 22 cuts (Total 39), LP: 27199.000000 (0.07 seconds)
# Found  0 CLOSE tighten_lp cuts (viol -0.0000) in 0.00 seconds
# Found  4 double deckers (viol 1.1429) in 0.03 seconds
#   Add  4 cuts (Total 43), LP: 27199.000000 (0.05 seconds)
# Found  0 CLOSE double deckers (viol -0.0000) in 0.00 seconds
# Found  0 Handling Inequalities (viol -0.0000) in 0.00 seconds
# Found  3 teethed combs (viol 0.4286) in 0.01 seconds
#   Add  3 cuts (Total 46), LP: 27199.000000 (0.06 seconds)
# integral solution not connected
# CCtsp_generate_edges (20231)
# Time for Add edges optimize: 0.05 seconds (0.56 total in 6 calls)
# CCtsp_generate_edges (20231)
# Time for Add edges: 0.05 seconds (0.59 total in 3 calls)
# (SPARSE) 24 edges added, penalty -0.000000, val 27199.000000
# Time for Sparse edge check: 0.05 seconds (0.59 total in 3 calls)
# Write Pool: 14 cuts
# Time for Cutting inside loop: 0.66 seconds (1.59 total in 3 calls)
# LP has:  123 rows  531 columns  4449 nonzeros
# Loading lp...done in 0.01 seconds
# LP has:  123 rows  531 columns  2769 nonzeros
# Found  0 connect cuts in 0.00 seconds
# Found  1 segment cuts in 0.00 seconds
#   Add  1 cuts (Total 47), LP: 27199.000000 (0.07 seconds)
# Found  0 Fast Blossoms in 0.00 seconds
# Found  2 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  2 cuts (Total 49), LP: 27199.000000 (0.11 seconds)
# Block Combs
#   Type 0: 4 cuts  0.7500 max violation  0.02 seconds
#   Type 1: 7 cuts  0.7500 max violation  0.00 seconds
#   Type 2: 4 cuts  1.2500 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 4 cuts  1.2500 max violation  0.00 seconds
#   Olaf 2: 6 cuts  0.2500 max violation  0.01 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.06
# Found 25 block_combs in 0.06 seconds
#   Add 25 cuts (Total 74), LP: 27199.000000 (0.12 seconds)
# Found  2 exact subtours in 0.00 seconds
#   Add  2 cuts (Total 76), LP: 27199.000000 (0.10 seconds)
# Found 21 tighten_lp cuts (viol 0.3333) in 0.02 seconds
#   Add 21 cuts (Total 97), LP: 27199.000000 (0.14 seconds)
# Found  1 CLOSE tighten_lp cuts (viol 0.0122) in 0.00 seconds
#   Add  1 cuts (Total 98), LP: 27199.000000 (0.11 seconds)
# Integral Solution of Value 27199.00
# CCtsp_generate_edges (20231)
# Time for Add edges: 0.01 seconds (0.60 total in 4 calls)
# (SPARSE) 0 edges added, penalty 0.000000, val 27199.000000
# Time for Sparse edge check: 0.01 seconds (0.60 total in 4 calls)
# Write Pool: 14 cuts
# Time for Cutting inside loop: 0.77 seconds (2.35 total in 4 calls)
# CCtsp_init_edgegenerator (-1)
# CCtsp_generate_edges (20231)
# Time for Add edges: 0.00 seconds (0.60 total in 5 calls)
# 0 edges added, penalty 0.000000
# New lower bound: 27199.000000
# Time for Full edge check: 0.00 seconds (0.00 total in 1 calls)
# Time for Cutting Loop: 2.36 seconds (2.36 total in 1 calls)
# Number of outside rounds: 1
# CCtsp_x_greedy_tour ...
# 76 edges in x-tour
# tour length: 27199.00 (0.00 seconds)
# Cannot run quadrant nearest with JUNK norms
# Trying 4-nearest instead
# Using junk-norm nearest code
#  242 edges
# Quad Nearest added 242 edges (0.00 seconds)
# Edgegen total edges: 242 (0.00 seconds)
# x-heuristic lk  gives: 27199.00
# Upperbound from x-heuristic: 27199.00
# Exact Price Time: 0.02 seconds
# Exact lower bound: 27199.000000
# DIFF: 0.000000
# Established Bound: 27199
# Optimal tour: 27199
# Total Time to solve TSP: 6.74
# Problem Name: 1Kzd8jonR1022i8dL8eDda
# Problem Type: TSP
# Number of Nodes: 9
# Explicit Lengths (CC_MATRIXNORM)
# CCtsp_solve_dat ...
# Finding a good tour for compression ...
# linkern ...
# Less than 10 nodes, setting repeatcount to 0
# Setting kick type to close
# Starting Cycle: 7063
# LK Cycle: 7063
# Best cycle length: 7063
# Lin-Kernighan Running Time: 0.00
# LK Initial Run: 7063.0
# Less than 10 nodes, setting repeatcount to 0
# LK Run 0: 7063.0
# Less than 10 nodes, setting repeatcount to 0
# LK Run from best tour: 7063.0
# Time to find compression tour: 0.01 (seconds)
# Set initial upperbound to 7063 (from tour)
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Fractional Matching: 7063.0
# Initial Running Time: 0.00 (seconds)
# Basis Running Time: 0.00 (seconds)
# Total fractional matching time: 0.00 (seconds)
# Total Time for first_lp: 0.00 (seconds)
# Setting upperbound to the initial bound: 7063.00
# Loading lp...done in 0.00 seconds
# LP has:  9 rows  13 columns  26 nonzeros
# Dual opt returned after 0.00 seconds
# Initial LP value: 7063.000000
# Setting tolerances: next cuts 0.0100 next round 0.0010
# CCtsp_init_edgegenerator (50)
# Using junk-norm nearest code
#  36 edges
# LP has:  9 rows  13 columns  26 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  9 rows  13 columns  26 nonzeros
# Integral Solution of Value 7063.00
# CCtsp_generate_edges (20027)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 1 calls)
# CCtsp_generate_edges (20027)
# Time for Add edges: 0.00 seconds (0.00 total in 1 calls)
# (SPARSE) 10 edges added, penalty 0.000000, val 7063.000000
# Time for Sparse edge check: 0.00 seconds (0.00 total in 1 calls)
# Write Pool: 0 cuts
# Time for Cutting inside loop: 0.02 seconds (0.02 total in 1 calls)
# CCtsp_init_edgegenerator (-1)
# CCtsp_generate_edges (20027)
# Time for Add edges: 0.00 seconds (0.00 total in 2 calls)
# 0 edges added, penalty 0.000000
# New lower bound: 7063.000000
# Time for Full edge check: 0.00 seconds (0.00 total in 1 calls)
# Time for Cutting Loop: 0.05 seconds (0.05 total in 1 calls)
# Number of outside rounds: 1
# CCtsp_x_greedy_tour ...
# 8 edges in x-tour
# tour length: 7063.00 (0.00 seconds)
# Cannot run quadrant nearest with JUNK norms
# Trying 4-nearest instead
# Using junk-norm nearest code
#  23 edges
# Quad Nearest added 23 edges (0.00 seconds)
# Edgegen total edges: 23 (0.00 seconds)
# Less than 10 nodes, setting repeatcount to 0
# x-heuristic lk  gives: 7063.00
# Exact Price Time: 0.00 seconds
# Exact lower bound: 7063.000000
# DIFF: 0.000000
# Established Bound: 7063
# Optimal tour: 7063
# Total Time to solve TSP: 0.07
# Problem Name: 3bxNKleDijOT6Did05jINs
# Problem Type: TSP
# Number of Nodes: 100
# Explicit Lengths (CC_MATRIXNORM)
# CCtsp_solve_dat ...
# Finding a good tour for compression ...
# linkern ...
# Setting kick type to close
# Starting Cycle: 54202
#    0 Steps   Best: 53732   0.02 seconds
#    4 Steps   Best: 53728   0.06 seconds
#    5 Steps   Best: 53644   0.07 seconds
#   11 Steps   Best: 53634   0.13 seconds
#   18 Steps   Best: 53452   0.19 seconds
#   19 Steps   Best: 53387   0.20 seconds
#   50 Total Steps.
# Best cycle length: 53387
# Lin-Kernighan Running Time: 0.49
# LK Initial Run: 53387.0
# LK Run 0: 53377.0
# LK Run from best tour: 53377.0
# Time to find compression tour: 1.88 (seconds)
# Set initial upperbound to 53377 (from tour)
# Fractional Matching: 50566.0
# Initial Running Time: 0.00 (seconds)
# Basis Running Time: 0.00 (seconds)
# Total fractional matching time: 0.00 (seconds)
# Total Time for first_lp: 0.00 (seconds)
# Setting upperbound to the initial bound: 53377.00
# Loading lp...done in 0.01 seconds
# LP has:  100 rows  234 columns  468 nonzeros
# Dual opt returned after 0.00 seconds
# Initial LP value: 50566.000000
# Setting tolerances: next cuts 28.1100 next round 2.8110
# CCtsp_init_edgegenerator (50)
# Using junk-norm nearest code
#  3199 edges
# LP has:  100 rows  234 columns  468 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  100 rows  234 columns  468 nonzeros
# Found 13 connect cuts in 0.00 seconds
#   Add 13 cuts (Total 10), LP: 52483.000000 (0.02 seconds)
# Found  2 segment cuts in 0.00 seconds
#   Add  2 cuts (Total 12), LP: 52596.000000 (0.01 seconds)
# Found  4 Fast Blossoms in 0.00 seconds
#   Add  4 cuts (Total 14), LP: 52683.000000 (0.00 seconds)
# integral solution not connected
# Found  0 Groetschel-Holland Blossoms in 0.00 seconds
# Block Combs
#   Type 0: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.00
# Found  0 block_combs in 0.00 seconds
# Found 12 exact subtours in 0.00 seconds
#   Add 12 cuts (Total 21), LP: 53050.500000 (0.04 seconds)
# Found 18 tighten_lp cuts (viol 1.0000) in 0.00 seconds
#   Add 18 cuts (Total 27), LP: 53160.500000 (0.06 seconds)
# Found  2 CLOSE tighten_lp cuts (viol 0.5000) in 0.00 seconds
#   Add  2 cuts (Total 29), LP: 53180.000000 (0.00 seconds)
# integral solution not connected
# Found  0 double deckers (viol -0.0000) in 0.00 seconds
# Found  0 CLOSE double deckers (viol -0.0000) in 0.00 seconds
# Found  0 Handling Inequalities (viol -0.0000) in 0.00 seconds
# Found  0 teethed combs (viol -0.0000) in 0.00 seconds
# CCtsp_generate_edges (20300)
# Time for Add edges optimize: 0.05 seconds (0.05 total in 1 calls)
# Time for Add edges optimize: 0.06 seconds (0.11 total in 2 calls)
# CCtsp_generate_edges (20300)
# Time for Add edges optimize: 0.03 seconds (0.14 total in 3 calls)
# CCtsp_generate_edges (20300)
# Time for Add edges: 0.15 seconds (0.15 total in 1 calls)
# (SPARSE) 172 edges added, penalty 0.000000, val 52302.000000
# Time for Sparse edge check: 0.15 seconds (0.15 total in 1 calls)
# Write Pool: 2 cuts
# Time for Cutting inside loop: 0.32 seconds (0.32 total in 1 calls)
# LP has:  129 rows  406 columns  1829 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  129 rows  406 columns  1134 nonzeros
# integral solution not connected
# Found 11 connect cuts in 0.00 seconds
#   Add 11 cuts (Total 36), LP: 53015.500000 (0.09 seconds)
# Found  5 segment cuts in 0.00 seconds
#   Add  5 cuts (Total 39), LP: 53038.500000 (0.01 seconds)
# Found  4 Fast Blossoms in 0.00 seconds
#   Add  4 cuts (Total 43), LP: 53038.500000 (0.07 seconds)
# Found  4 Groetschel-Holland Blossoms in 0.01 seconds
#   Add  4 cuts (Total 47), LP: 53039.000000 (0.10 seconds)
# Block Combs
#   Type 0: 3 cuts  1.0000 max violation  0.01 seconds
#   Type 1: 3 cuts  1.0000 max violation  0.01 seconds
#   Type 2: 1 cuts  1.0000 max violation  0.00 seconds
#   Type 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 1 cuts  1.0000 max violation  0.01 seconds
#   Olaf 2: 2 cuts  1.0000 max violation  0.01 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.01 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.06
# Found 10 block_combs in 0.06 seconds
#   Add 10 cuts (Total 53), LP: 53047.750000 (0.06 seconds)
# Found  2 exact subtours in 0.00 seconds
#   Add  2 cuts (Total 54), LP: 53067.166667 (0.13 seconds)
# Found 13 tighten_lp cuts (viol 0.8333) in 0.02 seconds
#   Add 13 cuts (Total 57), LP: 53081.500000 (0.06 seconds)
# Found  2 CLOSE tighten_lp cuts (viol 0.2500) in 0.00 seconds
#   Add  2 cuts (Total 58), LP: 53086.500000 (0.20 seconds)
# Found 28 double deckers (viol 1.8333) in 0.07 seconds
#   Add 28 cuts (Total 60), LP: 53088.375000 (0.33 seconds)
# Found  0 CLOSE double deckers (viol -0.0000) in 0.03 seconds
# Found  0 Handling Inequalities (viol -0.0000) in 0.01 seconds
# Found  4 teethed combs (viol 1.5000) in 0.01 seconds
#   Add  4 cuts (Total 64), LP: 53088.375000 (0.00 seconds)
# CCtsp_generate_edges (20300)
# Time for Add edges optimize: 0.14 seconds (0.28 total in 4 calls)
# CCtsp_generate_edges (20300)
# Time for Add edges optimize: 0.11 seconds (0.39 total in 5 calls)
# CCtsp_generate_edges (20300)
# Time for Add edges: 0.26 seconds (0.41 total in 2 calls)
# (SPARSE) 14 edges added, penalty 0.000000, val 53085.500000
# Time for Sparse edge check: 0.26 seconds (0.41 total in 2 calls)
# Write Pool: 22 cuts
# Time for Cutting inside loop: 1.56 seconds (1.88 total in 2 calls)
# LP has:  164 rows  420 columns  6498 nonzeros
# Loading lp...done in 0.01 seconds
# LP has:  164 rows  420 columns  2685 nonzeros
# Found  1 connect cuts in 0.00 seconds
#   Add  1 cuts (Total 64), LP: 53092.625000 (0.01 seconds)
# Found  6 segment cuts in 0.00 seconds
#   Add  6 cuts (Total 64), LP: 53240.000000 (0.17 seconds)
# Found  2 Fast Blossoms in 0.00 seconds
#   Add  2 cuts (Total 66), LP: 53240.000000 (0.09 seconds)
# Found  2 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  2 cuts (Total 68), LP: 53241.250000 (0.20 seconds)
# Block Combs
#   Type 0: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 1: 0 cuts  0.0000 max violation  0.01 seconds
#   Type 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 2: 1 cuts  0.5000 max violation  0.00 seconds
#   Olaf 3: 2 cuts  1.5000 max violation  0.01 seconds
#   Olaf 4: 2 cuts  1.5000 max violation  0.00 seconds
#   Total Time in block_combs: 0.04
# Found  5 block_combs in 0.04 seconds
#   Add  5 cuts (Total 73), LP: 53241.250000 (0.20 seconds)
# Found  1 exact subtours in 0.00 seconds
#   Add  1 cuts (Total 70), LP: 53242.000000 (0.02 seconds)
# Integral Solution of Value 53242.00
# CCtsp_generate_edges (20300)
# Time for Add edges optimize: 0.12 seconds (0.51 total in 6 calls)
# CCtsp_generate_edges (20300)
# Time for Add edges: 0.15 seconds (0.56 total in 3 calls)
# (SPARSE) 7 edges added, penalty 0.000000, val 53240.000000
# Time for Sparse edge check: 0.15 seconds (0.56 total in 3 calls)
# Write Pool: 30 cuts
# Time for Cutting inside loop: 0.94 seconds (2.81 total in 3 calls)
# LP has:  170 rows  427 columns  3286 nonzeros
# Loading lp...done in 0.01 seconds
# LP has:  170 rows  427 columns  2883 nonzeros
# Integral Solution of Value 53240.00
# CCtsp_generate_edges (20300)
# Time for Add edges: 0.00 seconds (0.56 total in 4 calls)
# (SPARSE) 0 edges added, penalty 0.000000, val 53240.000000
# Time for Sparse edge check: 0.00 seconds (0.56 total in 4 calls)
# recomputing rownorms ...
# Write Pool: 30 cuts
# Time for Cutting inside loop: 0.05 seconds (2.86 total in 4 calls)
# CCtsp_init_edgegenerator (-1)
# CCtsp_generate_edges (20300)
# Time for Add edges optimize: 0.00 seconds (0.52 total in 7 calls)
# CCtsp_generate_edges (20300)
# Time for Add edges: 0.01 seconds (0.57 total in 5 calls)
# 4 edges added, penalty 0.000000
# New lower bound: 53240.000000
# Time for Full edge check: 0.01 seconds (0.01 total in 1 calls)
# Time for Cutting Loop: 2.94 seconds (2.94 total in 1 calls)
# Number of outside rounds: 1
# CCtsp_x_greedy_tour ...
# 99 edges in x-tour
# tour length: 53240.00 (0.00 seconds)
# Cannot run quadrant nearest with JUNK norms
# Trying 4-nearest instead
# Using junk-norm nearest code
#  269 edges
# Quad Nearest added 269 edges (0.00 seconds)
# Edgegen total edges: 269 (0.00 seconds)
# x-heuristic lk  gives: 53240.00
# Upperbound from x-heuristic: 53240.00
# Exact Price Time: 0.01 seconds
# Exact lower bound: 53240.000000
# DIFF: 0.000000
# Established Bound: 53240
# Optimal tour: 53240
# Total Time to solve TSP: 5.67
