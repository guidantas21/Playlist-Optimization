# %%
from concorde.tsp import TSPSolver
from concorde.tests.data_utils import get_dataset_path
import tsplib95

import numpy as np
import pandas as pd
import json

# %%
with open('parameters.json') as f:
    parameters = json.load(f)

# %%
with open('playlist.json') as f:
    data = json.load(f)

data
# Out:
# [{'id': '0NWPxcsf5vdjdiFUI8NgkP',
#   'name': 'Hey Joe',
#   'album': 'Are You Experienced',
#   'artist': 'Jimi Hendrix',
#   'genres': ['acid rock',
#    'album rock',
#    'classic rock',
#    'hard rock',
#    'proto-metal',
#    'psychedelic rock',
#    'rock'],
#   'related_artists': ['Cream',
#    'Canned Heat',
#    'The Yardbirds',
#    'Derek & The Dominos',
#    'Steppenwolf',
#    'Janis Joplin',
#    'Ten Years After',
#    'Free',
#    'Jefferson Airplane',
#    'The Doors',
#    'The Animals',
#    'Big Brother & The Holding Company',
#    'Stevie Ray Vaughan',
#    'Rory Gallagher',
#    'Jim Morrison',
#    'Traffic',
#    'John Mayall & The Bluesbreakers',
#    'Allman Brothers Band',
#    'Albert King',
#    'Freddie King'],
#   'related_genres': ['mellow gold',
#    'soft rock',
#    'singer-songwriter',
#    'art rock',
#    'instrumental rock',
#    'blues rock',
#    'roots rock',
#    'british invasion',
#    'traditional blues',
#    'electric blues',
#    'memphis soul',
#    'folk',
#    'progressive rock',
#    'folk rock',
#    'texas blues',
#    'heartland rock',
#    'symphonic rock',
#    'british blues',
#    'southern rock',
#    'country rock',
#    'blues',
#    'jam band',
#    'protopunk',
#    'soul blues',
#    'supergroup',
#    'classic canadian rock'],
#   'generic_genres': ['rock',
#    'rock',
#    'rock',
#    'rock',
#    'metal',
#    'rock',
#    'rock',
#    'rock',
#    'rock',
#    'rock',
#    'rock',
#    'blues',
#    'rock',
#    'invasion',
#    'blues',
#    'blues',
#    'soul',
#    'folk',
#    'rock',
#    'rock',
#    'folk',
#    'blues',
#    'rock',
#    'rock',
#    'blues',
#    'rock',
#    'rock',
#    'country',
#    'blues',
#    'punk',
#    'blues',
#    'soul',
#    'rock'],
#   'release_date': '1967-05-12',
#   'duration_ms': 210160,
#   'popularity': 72,
#   'acousticness': 0.00603,
#   'danceability': 0.346,
#   'energy': 0.768,
#   'instrumentalness': 0.38,
#   'key': 9,
#   'liveness': 0.0244,
#   'loudness': -5.695,
#   'mode': 1,
#   'speechiness': 0.0377,
#   'tempo': 169.492,
#   'time_signature': 4,
#   'valence': 0.532},
#  {'id': '2MuWTIM3b0YEAskbeeFE1i',
#   'name': 'Master Of Puppets',
#   'album': 'Master Of Puppets (Remastered)',
#   'artist': 'Metallica',
#   'genres': ['hard rock',
#    'metal',
#    'old school thrash',
#    'rock',
#    'thrash metal'],
#   'related_artists': ['Megadeth',
#    'Slayer',
#    'Pantera',
#    'Judas Priest',
#    'Motörhead',
#    'Black Label Society',
#    'Anthrax',
#    'Iron Maiden',
#    'Testament',
#    'Machine Head',
#    'Black Sabbath',
#    'Danzig',
#    'Ozzy Osbourne',
#    'Sepultura',
#    'Dio',
#    'White Zombie',
#    'Alice In Chains',
#    'Kreator',
#    'Lamb of God',
#    'Airbourne'],
#   'related_genres': ['brazilian metal',
#    'latin metal',
#    'progressive groove metal',
#    'virginia metal',
#    'melodic groove metal',
#    'german metal',
#    'speed metal',
#    'grunge',
#    'nwobhm',
#    'punk',
#    'rap metal',
#    'uk doom metal',
#    'death metal',
#    'classic rock',
#    'stoner rock',
#    'industrial metal',
#    'texas metal',
#    'alternative rock',
#    'nu metal',
#    'brazilian thrash metal',
#    'album rock',
#    'melodic thrash',
#    'brazilian groove metal',
#    'alternative metal',
#    'groove metal',
#    'glam metal',
#    'deathrash',
#    'german thrash metal',
#    'metal mineiro',
#    'post-grunge',
#    'melodic metalcore',
#    'birmingham metal'],
#   'generic_genres': ['rock',
#    'metal',
#    'rock',
#    'metal',
#    'metal',
#    'metal',
#    'latin',
#    'metal',
#    'metal',
#    'metal',
#    'metal',
#    'metal',
#    'grunge',
#    'punk',
#    'rap',
#    'metal',
#    'metal',
#    'metal',
#    'rock',
#    'rock',
#    'metal',
#    'metal',
#    'rock',
#    'metal',
#    'metal',
#    'rock',
#    'metal',
#    'metal',
#    'metal',
#    'metal',
#    'metal',
#    'metal',
#    'post-grunge',
#    'grunge',
#    'metal',
#    'metalcore',
#    'metal'],
#   'release_date': '1986-03-03',
#   'duration_ms': 515386,
#   'popularity': 80,
#   'acousticness': 0.000647,
#   'danceability': 0.543,
#   'energy': 0.836,
#   'instrumentalness': 0.431,
#   'key': 4,
#   'liveness': 0.153,
#   'loudness': -9.11,
#   'mode': 0,
#   'speechiness': 0.0353,
#   'tempo': 105.173,
#   'time_signature': 4,
#   'valence': 0.56},
#  {'id': '0V3wPSX9ygBnCm8psDIegu',
#   'name': 'Anti-Hero',
#   'album': 'Midnights',
#   'artist': 'Taylor Swift',
#   'genres': ['pop'],
#   'related_artists': ['Demi Lovato',
#    'Selena Gomez',
#    'Harry Styles',
#    'Alessia Cara',
#    'Katy Perry',
#    'One Direction',
#    'Meghan Trainor',
#    'Camila Cabello',
#    'Niall Horan',
#    'Ariana Grande',
#    'Selena Gomez & The Scene',
#    'Fifth Harmony',
#    'Halsey',
#    'Dua Lipa',
#    'The 1975',
#    'Jonas Brothers',
#    'Troye Sivan',
#    '5 Seconds of Summer',
#    'Little Mix',
#    'Sabrina Carpenter'],
#   'related_genres': ['viral pop',
#    'rock',
#    'australian pop',
#    'etherpop',
#    'modern alternative rock',
#    'canadian pop',
#    'girl group',
#    'modern rock',
#    'canadian contemporary r&b',
#    'boy band',
#    'electropop',
#    'indie poptimism',
#    'hip pop',
#    'dance pop',
#    'talent show',
#    'post-teen pop',
#    'pov: indie',
#    'uk pop'],
#   'generic_genres': ['pop',
#    'pop',
#    'rock',
#    'pop',
#    'pop',
#    'rock',
#    'pop',
#    'rock',
#    'r&b',
#    'pop',
#    'electro',
#    'electropop',
#    'pop',
#    'pop',
#    'hip pop',
#    'pop',
#    'dance',
#    'pop',
#    'pop'],
#   'release_date': '2022-10-21',
#   'duration_ms': 200690,
#   'popularity': 93,
#   'acousticness': 0.13,
#   'danceability': 0.637,
#   'energy': 0.643,
#   'instrumentalness': 1.8e-06,
#   'key': 4,
#   'liveness': 0.142,
#   'loudness': -6.571,
#   'mode': 1,
#   'speechiness': 0.0519,
#   'tempo': 97.008,
#   'time_signature': 4,
#   'valence': 0.533},
#  {'id': '4N0TP4Rmj6QQezWV88ARNJ',
#   'name': 'Superstition',
#   'album': 'Talking Book',
#   'artist': 'Stevie Wonder',
#   'genres': ['motown', 'soul'],
#   'related_artists': ['The Isley Brothers',
#    'Marvin Gaye',
#    'Commodores',
#    'The Temptations',
#    'Bill Withers',
#    'The Spinners',
#    'Four Tops',
#    'Smokey Robinson & The Miracles',
#    'Curtis Mayfield',
#    'The Jacksons',
#    'Sly & The Family Stone',
#    'The Supremes',
#    'Gladys Knight & The Pips',
#    'Al Green',
#    'Roberta Flack',
#    "The O'Jays",
#    'Kool & The Gang',
#    'Wilson Pickett',
#    'The Miracles',
#    'Diana Ross'],
#   'related_genres': ['mellow gold',
#    'soft rock',
#    'quiet storm',
#    'disco',
#    'adult standards',
#    'vocal jazz',
#    'psychedelic soul',
#    'southern soul',
#    'p funk',
#    'philly soul',
#    'funk rock',
#    'funk',
#    'neo soul',
#    'memphis soul',
#    'soul blues',
#    'classic girl group',
#    'rhythm and blues',
#    'classic soul',
#    'northern soul',
#    'chicago soul'],
#   'generic_genres': ['motown',
#    'soul',
#    'rock',
#    'disco',
#    'jazz',
#    'soul',
#    'soul',
#    'soul',
#    'rock',
#    'soul',
#    'soul',
#    'blues',
#    'soul',
#    'blues',
#    'soul',
#    'soul',
#    'soul'],
#   'release_date': '1972-10-28',
#   'duration_ms': 266133,
#   'popularity': 69,
#   'acousticness': 0.0598,
#   'danceability': 0.611,
#   'energy': 0.578,
#   'instrumentalness': 0.0219,
#   'key': 1,
#   'liveness': 0.0983,
#   'loudness': -14.171,
#   'mode': 1,
#   'speechiness': 0.0676,
#   'tempo': 100.625,
#   'time_signature': 4,
#   'valence': 0.884},
#  {'id': '0PUi8C3der9IVNFaksxTiw',
#   'name': 'Rain',
#   'album': 'Candlebox',
#   'artist': 'Candlebox',
#   'genres': ['alternative metal',
#    'alternative rock',
#    'grunge',
#    'nu metal',
#    'post-grunge'],
#   'related_artists': ['Days Of The New',
#    'Mad Season',
#    'Seven Mary Three',
#    'Temple Of The Dog',
#    'Bush',
#    'Mother Love Bone',
#    'Stone Temple Pilots',
#    'Local H',
#    'Blind Melon',
#    'Jerry Cantrell',
#    'Sponge',
#    'Screaming Trees',
#    'Soundgarden',
#    'Alice In Chains',
#    "Jane's Addiction",
#    'Silverchair',
#    'Soul Asylum',
#    'Toadies',
#    'Chris Cornell',
#    'Collective Soul'],
#   'related_genres': ['australian alternative rock',
#    'rock',
#    'funk metal',
#    'supergroup',
#    'hard rock',
#    'pop rock',
#    'blues rock',
#    'classic rock',
#    'permanent wave',
#    'australian psych',
#    'funk rock'],
#   'generic_genres': ['metal',
#    'rock',
#    'grunge',
#    'metal',
#    'post-grunge',
#    'grunge',
#    'rock',
#    'rock',
#    'metal',
#    'rock',
#    'pop',
#    'rock',
#    'rock',
#    'blues',
#    'rock',
#    'rock'],
#   'release_date': '1993-07-16',
#   'duration_ms': 418426,
#   'popularity': 36,
#   'acousticness': 0.0358,
#   'danceability': 0.406,
#   'energy': 0.849,
#   'instrumentalness': 0.000199,
#   'key': 9,
#   'liveness': 0.057,
#   'loudness': -7.109,
#   'mode': 1,
#   'speechiness': 0.0755,
#   'tempo': 101.886,
#   'time_signature': 4,
#   'valence': 0.346},
#  {'id': '6gZVQvQZOFpzIy3HblJ20F',
#   'name': 'Man in the Box',
#   'album': 'Facelift',
#   'artist': 'Alice In Chains',
#   'genres': ['alternative metal',
#    'alternative rock',
#    'grunge',
#    'hard rock',
#    'nu metal',
#    'rock'],
#   'related_artists': ['Mad Season',
#    'Soundgarden',
#    'Temple Of The Dog',
#    'Stone Temple Pilots',
#    'Jerry Cantrell',
#    'Mother Love Bone',
#    'Days Of The New',
#    'Blind Melon',
#    'Candlebox',
#    "Jane's Addiction",
#    'Screaming Trees',
#    'Bush',
#    'Silverchair',
#    'Chris Cornell',
#    'Faith No More',
#    'Local H',
#    'Audioslave',
#    'Mudhoney',
#    'Velvet Revolver',
#    'Filter'],
#   'related_genres': ['australian alternative rock',
#    'industrial metal',
#    'punk',
#    'rap metal',
#    'funk metal',
#    'supergroup',
#    'glam metal',
#    'post-grunge',
#    'pop rock',
#    'blues rock',
#    'classic rock',
#    'permanent wave',
#    'australian psych',
#    'funk rock'],
#   'generic_genres': ['metal',
#    'rock',
#    'grunge',
#    'rock',
#    'metal',
#    'rock',
#    'rock',
#    'metal',
#    'punk',
#    'rap',
#    'metal',
#    'metal',
#    'metal',
#    'post-grunge',
#    'grunge',
#    'pop',
#    'rock',
#    'rock',
#    'blues',
#    'rock',
#    'rock'],
#   'release_date': '1990-08-01',
#   'duration_ms': 285200,
#   'popularity': 77,
#   'acousticness': 0.00045,
#   'danceability': 0.355,
#   'energy': 0.791,
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.0969,
#   'loudness': -7.565,
#   'mode': 1,
#   'speechiness': 0.0453,
#   'tempo': 106.392,
#   'time_signature': 4,
#   'valence': 0.758},
#  {'id': '6MKqed1tCXHRonfqhwPCET',
#   'name': 'When A Blind Man Cries',
#   'album': 'Hardwired…To Self-Destruct (Deluxe)',
#   'artist': 'Metallica',
#   'genres': ['hard rock',
#    'metal',
#    'old school thrash',
#    'rock',
#    'thrash metal'],
#   'related_artists': ['Megadeth',
#    'Slayer',
#    'Pantera',
#    'Judas Priest',
#    'Motörhead',
#    'Black Label Society',
#    'Anthrax',
#    'Iron Maiden',
#    'Testament',
#    'Machine Head',
#    'Black Sabbath',
#    'Danzig',
#    'Ozzy Osbourne',
#    'Sepultura',
#    'Dio',
#    'White Zombie',
#    'Alice In Chains',
#    'Kreator',
#    'Lamb of God',
#    'Airbourne'],
#   'related_genres': ['brazilian metal',
#    'latin metal',
#    'progressive groove metal',
#    'virginia metal',
#    'melodic groove metal',
#    'german metal',
#    'speed metal',
#    'grunge',
#    'nwobhm',
#    'punk',
#    'rap metal',
#    'uk doom metal',
#    'death metal',
#    'classic rock',
#    'stoner rock',
#    'industrial metal',
#    'texas metal',
#    'alternative rock',
#    'nu metal',
#    'brazilian thrash metal',
#    'album rock',
#    'melodic thrash',
#    'brazilian groove metal',
#    'alternative metal',
#    'groove metal',
#    'glam metal',
#    'deathrash',
#    'german thrash metal',
#    'metal mineiro',
#    'post-grunge',
#    'melodic metalcore',
#    'birmingham metal'],
#   'generic_genres': ['rock',
#    'metal',
#    'rock',
#    'metal',
#    'metal',
#    'metal',
#    'latin',
#    'metal',
#    'metal',
#    'metal',
#    'metal',
#    'metal',
#    'grunge',
#    'punk',
#    'rap',
#    'metal',
#    'metal',
#    'metal',
#    'rock',
#    'rock',
#    'metal',
#    'metal',
#    'rock',
#    'metal',
#    'metal',
#    'rock',
#    'metal',
#    'metal',
#    'metal',
#    'metal',
#    'metal',
#    'metal',
#    'post-grunge',
#    'grunge',
#    'metal',
#    'metalcore',
#    'metal'],
#   'release_date': '2016-11-18',
#   'duration_ms': 275013,
#   'popularity': 48,
#   'acousticness': 0.000368,
#   'danceability': 0.453,
#   'energy': 0.77,
#   'instrumentalness': 0.0627,
#   'key': 8,
#   'liveness': 0.116,
#   'loudness': -5.783,
#   'mode': 1,
#   'speechiness': 0.0392,
#   'tempo': 134.644,
#   'time_signature': 4,
#   'valence': 0.296},
#  {'id': '50DMG6AvtNzbrxMc62w6ph',
#   'name': 'Bold as Love',
#   'album': 'Continuum',
#   'artist': 'John Mayer',
#   'genres': ['neo mellow', 'singer-songwriter'],
#   'related_artists': ['Gavin DeGraw',
#    'Eric Hutchinson',
#    'Jack Johnson',
#    'Amos Lee',
#    'Jason Mraz',
#    'James Morrison',
#    'Mat Kearney',
#    'Ray LaMontagne',
#    'Five For Fighting',
#    'Donavon Frankenreiter',
#    'DISPATCH',
#    'Colbie Caillat',
#    'Rob Thomas',
#    'David Gray',
#    'Matt Nathanson',
#    'Parachute',
#    'Mat McHugh',
#    'Ben Rector',
#    'James Bay',
#    'Ingrid Michaelson'],
#   'related_genres': ['viral pop',
#    'lds youth',
#    'pop',
#    'uk pop',
#    'pop rock',
#    'neon pop punk',
#    'piano rock',
#    'lilith',
#    'jam band',
#    'stomp and holler',
#    'folk-pop',
#    'dance pop',
#    'indie folk',
#    'modern folk rock',
#    'ectofolk',
#    'charlottesville indie',
#    'indiecoustica',
#    'post-grunge',
#    'permanent wave',
#    'acoustic pop'],
#   'generic_genres': ['pop',
#    'pop',
#    'pop',
#    'pop',
#    'rock',
#    'pop',
#    'punk',
#    'rock',
#    'pop',
#    'folk',
#    'k-pop',
#    'pop',
#    'dance',
#    'folk',
#    'rock',
#    'folk',
#    'folk',
#    'post-grunge',
#    'grunge',
#    'pop'],
#   'release_date': '2006-09-11',
#   'duration_ms': 258160,
#   'popularity': 53,
#   'acousticness': 0.0995,
#   'danceability': 0.439,
#   'energy': 0.59,
#   'instrumentalness': 0.00221,
#   'key': 1,
#   'liveness': 0.0718,
#   'loudness': -6.407,
#   'mode': 1,
#   'speechiness': 0.0417,
#   'tempo': 125.897,
#   'time_signature': 4,
#   'valence': 0.4},
#  {'id': '3a1lNhkSLSkpJE4MSHpDu9',
#   'name': 'Congratulations',
#   'album': 'Stoney (Deluxe)',
#   'artist': 'Post Malone',
#   'genres': ['dfw rap', 'melodic rap', 'pop', 'rap'],
#   'related_artists': ['Rae Sremmurd',
#    'Huncho Jack',
#    'A$AP Ferg',
#    '6LACK',
#    'Tyla Yaweh',
#    'The Kid LAROI',
#    'Quality Control',
#    'Migos',
#    'Quavo',
#    'Desiigner',
#    'NAV',
#    'SAINt JHN',
#    'Lil Mosey',
#    'Bazzi',
#    'Arizona Zervas',
#    'Fetty Wap',
#    'Young Thug',
#    'mike.',
#    'Jaden',
#    'Cordae'],
#   'related_genres': ['new jersey rap',
#    'atl hip hop',
#    'canadian trap',
#    'trap',
#    'rap conscient',
#    'viral trap',
#    'underground hip hop',
#    'australian hip hop',
#    'indie pop rap',
#    'southern hip hop',
#    'atl trap',
#    'mississippi hip hop',
#    'hip hop',
#    'pop rap',
#    'gangster rap',
#    'r&b',
#    'cali rap',
#    'slap house',
#    'canadian hip hop',
#    'rhode island rap'],
#   'generic_genres': ['rap',
#    'rap',
#    'pop',
#    'rap',
#    'rap',
#    'hip hop',
#    'rap',
#    'trap',
#    'rap',
#    'trap',
#    'rap',
#    'rap',
#    'trap',
#    'hip hop',
#    'hip hop',
#    'pop',
#    'rap',
#    'hip hop',
#    'rap',
#    'trap',
#    'hip hop',
#    'hip hop',
#    'pop',
#    'rap',
#    'rap',
#    'r&b',
#    'rap',
#    'hip hop',
#    'rap'],
#   'release_date': '2016-12-09',
#   'duration_ms': 220293,
#   'popularity': 84,
#   'acousticness': 0.215,
#   'danceability': 0.63,
#   'energy': 0.804,
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.253,
#   'loudness': -4.183,
#   'mode': 1,
#   'speechiness': 0.0363,
#   'tempo': 123.146,
#   'time_signature': 4,
#   'valence': 0.492}]

# %%
def compare_artist_album_similarity(data_a:dict, data_b:dict) -> int:
    distance = 0

    if (data_a["artist"] == data_b["artist"]):
        distance += parameters["same_artist_bonus"]
        
        if (data_a["album"] == data_b["album"]):
            distance += parameters["same_album_bonus"]

    return distance


def compare_intersections(a:list, b:list, multiplier:list) -> int:
    if a and b:
        set_a = set(a)
        set_b = set(b)

        intersection = set_a.intersection(set_b)

        intersection_size = len(intersection)

        if intersection_size > 0:
        
            total_size = len(set_a) + len(set_b)

            CONSTANT = 100

            similarity = (intersection_size / total_size) * CONSTANT

            return similarity *multiplier

    return 0

# %%
def initialize_adjacency_matrix(size:int) -> list:
    return [[0 for col in range(size)] for row in range(size)]


def populate_adjacency_matrix(adjacency_matrix:list, size:int) -> list:
    for i in range(size):
        for j in range(size):
            if i != j:
                distance = parameters['initial_distance']

                distance -= compare_artist_album_similarity(data[i], data[j])

                distance -= compare_intersections(
                    data[i]["genres"], data[j]["genres"], parameters["genres_intersection_multiplier"])
                distance -= compare_intersections(
                    data[i]["related_genres"], data[j]["related_genres"], parameters["related_genres_intersection_multiplier"])
                distance -= compare_intersections(
                    data[i]["related_artists"], data[j]["related_artists"], parameters["related_artists_intersection_multiplier"])
                distance -= compare_intersections(
                    data[i]["generic_genres"], data[j]["generic_genres"], parameters["generic_genres_intersection_multiplier"])

                adjacency_matrix[i][j] = int(distance);
    
    return adjacency_matrix


def print_adjacency_matrix(adjacency_matrix:list, size:int) -> None:
    for i in range(size):
        for j in range(size):
            print("{}".format(adjacency_matrix[i][j]), end=" ")
        print()    

def create_tsplib_file(adjacency_matrix, filename):
  with open(filename, 'w') as f:
    f.write('NAME: tsp_problem\n')
    f.write('COMMENT: This is a TSP problem.\n')
    f.write('DIMENSION: {}\n'.format(len(adjacency_matrix)))
    f.write('EDGE_WEIGHT_TYPE: EXPLICIT\n')
    f.write('EDGES:\n')

    for i in range(len(adjacency_matrix)):
      for j in range(i + 1, len(adjacency_matrix)):
        f.write('{} {} {}\n'.format(i, j, adjacency_matrix[i][j]))

# %%
SIZE = len(data)
adjacency_matrix = initialize_adjacency_matrix(SIZE)
adjacency_matrix = populate_adjacency_matrix(adjacency_matrix, SIZE)
# create_tsplib_file(adjacency_matrix, "test.tsp")
print_adjacency_matrix(adjacency_matrix, SIZE)
# Out:
# 0 879 986 922 935 853 879 953 1000
# 879 0 986 985 926 781 290 942 984
# 986 986 0 984 955 973 986 928 866
# 922 985 984 0 953 959 985 985 1000
# 935 926 955 953 0 483 926 917 981
# 853 781 973 959 483 0 781 902 969
# 879 290 986 985 926 781 0 942 984
# 953 942 928 985 917 902 942 0 984
# 1000 984 866 1000 981 969 984 984 0

# %%
distance_matrix = np.array([
    [0, 10, 15, 20, 25],
    [10, 0, 35, 25, 30],
    [15, 35, 0, 30, 40],
    [20, 25, 30, 0, 50],
    [25, 30, 40, 50, 0]
])

problem = tsplib95.models.StandardProblem()

problem.name = "test"
problem.type = "TSP"
problem.dimension = SIZE
problem.edge_weight_type = "EXPLICIT"
problem.edge_weight_format = "FULL_MATRIX"
problem.node_coord_type = "NO_COORDS"
problem.display_data_type = "NO_DISPLAY"
problem.edge_weights = np.array(adjacency_matrix).tolist()


problem.save("test1.tsp")

# %%
fname = get_dataset_path("berlin52")
solver = TSPSolver.from_tspfile("test1.tsp")

solution = solver.solve()

solution.tour
# Out:
# array([0, 3, 8, 2, 7, 4, 5, 6, 1], dtype=int32)
# Problem Name: test
# Problem Type: TSP
# Number of Nodes: 9
# Explicit Lengths (CC_MATRIXNORM)
# CCtsp_solve_dat ...
# Finding a good tour for compression ...
# linkern ...
# Less than 10 nodes, setting repeatcount to 0
# Setting kick type to close
# Starting Cycle: 7066
# LK Cycle: 7066
# Best cycle length: 7066
# Lin-Kernighan Running Time: 0.00
# LK Initial Run: 7066.0
# Less than 10 nodes, setting repeatcount to 0
# LK Run 0: 7066.0
# Less than 10 nodes, setting repeatcount to 0
# LK Run from best tour: 7066.0
# Time to find compression tour: 0.00 (seconds)
# Set initial upperbound to 7066 (from tour)
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Less than 10 nodes, setting repeatcount to 0
# Fractional Matching: 7066.0
# Initial Running Time: 0.00 (seconds)
# Basis Running Time: 0.00 (seconds)
# Total fractional matching time: 0.00 (seconds)
# Total Time for first_lp: 0.00 (seconds)
# Setting upperbound to the initial bound: 7066.00
# Loading lp...done in 0.00 seconds
# LP has:  9 rows  13 columns  26 nonzeros
# Dual opt returned after 0.00 seconds
# Initial LP value: 7066.000000
# Setting tolerances: next cuts 0.0100 next round 0.0010
# CCtsp_init_edgegenerator (50)
# Using junk-norm nearest code
#  36 edges
# LP has:  9 rows  13 columns  26 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  9 rows  13 columns  26 nonzeros
# Integral Solution of Value 7066.00
# CCtsp_generate_edges (20027)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 1 calls)
# CCtsp_generate_edges (20027)
# Time for Add edges: 0.00 seconds (0.00 total in 1 calls)
# (SPARSE) 10 edges added, penalty 0.000000, val 7066.000000
# Time for Sparse edge check: 0.00 seconds (0.00 total in 1 calls)
# Write Pool: 0 cuts
# Time for Cutting inside loop: 0.01 seconds (0.01 total in 1 calls)
# CCtsp_init_edgegenerator (-1)
# CCtsp_generate_edges (20027)
# Time for Add edges: 0.00 seconds (0.00 total in 2 calls)
# 0 edges added, penalty 0.000000
# New lower bound: 7066.000000
# Time for Full edge check: 0.00 seconds (0.00 total in 1 calls)
# Time for Cutting Loop: 0.01 seconds (0.01 total in 1 calls)
# Number of outside rounds: 1
# CCtsp_x_greedy_tour ...
# 8 edges in x-tour
# tour length: 7066.00 (0.00 seconds)
# Cannot run quadrant nearest with JUNK norms
# Trying 4-nearest instead
# Using junk-norm nearest code
#  23 edges
# Quad Nearest added 23 edges (0.00 seconds)
# Edgegen total edges: 23 (0.00 seconds)
# Less than 10 nodes, setting repeatcount to 0
# x-heuristic lk  gives: 7066.00
# Exact Price Time: 0.00 seconds
# Exact lower bound: 7066.000000
# DIFF: 0.000000
# Established Bound: 7066
# Optimal tour: 7066
# Total Time to solve TSP: 0.01
